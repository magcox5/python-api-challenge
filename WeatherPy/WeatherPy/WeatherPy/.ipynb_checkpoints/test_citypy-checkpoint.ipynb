# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import json
import requests
import time

# Import API key
from api_keys import api_key

# Incorporated citipy to determine city based on latitude and longitude
from citipy import citipy

# Output File (CSV)
output_data_file = "output_data/cities.csv"

# Range of latitudes and longitudes
lat_range = (-90, 90)
lng_range = (-180, 180)

# %%
# List for holding lat_lngs and cities
lat_lngs = []
cities = []

# Create a set of random lat and lng combinations
lats = np.random.uniform(low=-90.000, high=90.000, size=1500)
lngs = np.random.uniform(low=-180.000, high=180.000, size=1500)
lat_lngs = list(zip(lats, lngs))

i = 1
# Identify nearest city for each lat, lng combination
for lat_lng in lat_lngs:
#    city = citipy.nearest_city(lat_lng[0], lat_lng[1]).city_name
    city = citipy.nearest_city(lat_lng[0], lat_lng[1])
    print(city)
    city_name = city.city_name
    city_country = city.country_code
#    city_lat = city['coord']['lat']
#    city_lon = city['coord']['lon']
    print(city_name, city_country)

    # If the city is unique, then add it to a our cities list
    if city_name not in cities:
        cities.append(city_name)

# Print the city count to confirm sufficient count
len(cities)
# Out:
# <citipy.citipy.City object at 0x000001FC92176D08>
# carnarvon au
# {'city_name': 'carnarvon', 'country_code': 'au'}
# <citipy.citipy.City object at 0x000001FC933C82C8>
# rikitea pf
# {'city_name': 'rikitea', 'country_code': 'pf'}
# <citipy.citipy.City object at 0x000001FC9313BDC8>
# sikasso ml
# {'city_name': 'sikasso', 'country_code': 'ml'}
# <citipy.citipy.City object at 0x000001FC93CF7C48>
# kisanga tz
# {'city_name': 'kisanga', 'country_code': 'tz'}
# <citipy.citipy.City object at 0x000001FC93BED388>
# umm lajj sa
# {'city_name': 'umm lajj', 'country_code': 'sa'}
# <citipy.citipy.City object at 0x000001FC9399CEC8>
# egvekinot ru
# {'city_name': 'egvekinot', 'country_code': 'ru'}
# <citipy.citipy.City object at 0x000001FC93DB7348>
# barrow us
# {'city_name': 'barrow', 'country_code': 'us'}
# <citipy.citipy.City object at 0x000001FC92505AC8>
# qingyuan cn
# {'city_name': 'qingyuan', 'country_code': 'cn'}
# <citipy.citipy.City object at 0x000001FC93BEDD88>
# victoria sc
# {'city_name': 'victoria', 'country_code': 'sc'}
# <citipy.citipy.City object at 0x000001FC93C09508>
# jamestown sh
# {'city_name': 'jamestown', 'country_code': 'sh'}
# <citipy.citipy.City object at 0x000001FC92447F48>
# binga cd
# {'city_name': 'binga', 'country_code': 'cd'}
# <citipy.citipy.City object at 0x000001FC93A400C8>
# lavrentiya ru
# {'city_name': 'lavrentiya', 'country_code': 'ru'}
# <citipy.citipy.City object at 0x000001FC93A30588>
# kumeny ru
# {'city_name': 'kumeny', 'country_code': 'ru'}
# <citipy.citipy.City object at 0x000001FC92FA6D08>
# kearney us
# {'city_name': 'kearney', 'country_code': 'us'}
# <citipy.citipy.City object at 0x000001FC92148FC8>
# ushuaia ar
# {'city_name': 'ushuaia', 'country_code': 'ar'}
# <citipy.citipy.City object at 0x000001FC932A5A88>
# henties bay na
# {'city_name': 'henties bay', 'country_code': 'na'}
# <citipy.citipy.City object at 0x000001FC9243D588>
# tuktoyaktuk ca
# {'city_name': 'tuktoyaktuk', 'country_code': 'ca'}
# <citipy.citipy.City object at 0x000001FC933B15C8>
# paita pe
# {'city_name': 'paita', 'country_code': 'pe'}
# <citipy.citipy.City object at 0x000001FC92BDC048>
# westport ie
# {'city_name': 'westport', 'country_code': 'ie'}
# <citipy.citipy.City object at 0x000001FC924477C8>
# yellowknife ca
# {'city_name': 'yellowknife', 'country_code': 'ca'}
# <citipy.citipy.City object at 0x000001FC931253C8>
# taolanaro mg
# {'city_name': 'taolanaro', 'country_code': 'mg'}
# <citipy.citipy.City object at 0x000001FC93BE7988>
# zyryanka ru
# {'city_name': 'zyryanka', 'country_code': 'ru'}
# <citipy.citipy.City object at 0x000001FC92148FC8>
# ushuaia ar
# {'city_name': 'ushuaia', 'country_code': 'ar'}
# <citipy.citipy.City object at 0x000001FC9336B248>
# tuatapere nz
# {'city_name': 'tuatapere', 'country_code': 'nz'}
# <citipy.citipy.City object at 0x000001FC9372C448>
# saint-philippe re
# {'city_name': 'saint-philippe', 'country_code': 're'}
# <citipy.citipy.City object at 0x000001FC92407A88>
# lloydminster ca
# {'city_name': 'lloydminster', 'country_code': 'ca'}
# <citipy.citipy.City object at 0x000001FC93984E88>
# chunoyar ru
# {'city_name': 'chunoyar', 'country_code': 'ru'}
# <citipy.citipy.City object at 0x000001FC933C74C8>
# mataura pf
# {'city_name': 'mataura', 'country_code': 'pf'}
# <citipy.citipy.City object at 0x000001FC927B36C8>
# puerto ayora ec
# {'city_name': 'puerto ayora', 'country_code': 'ec'}
# <citipy.citipy.City object at 0x000001FC922F2808>
# itaituba br
# {'city_name': 'itaituba', 'country_code': 'br'}
# <citipy.citipy.City object at 0x000001FC931841C8>
# armeria mx
# {'city_name': 'armeria', 'country_code': 'mx'}
# <citipy.citipy.City object at 0x000001FC93358088>
# bluff nz
# {'city_name': 'bluff', 'country_code': 'nz'}
# <citipy.citipy.City object at 0x000001FC925C4F88>
# suarez co
# {'city_name': 'suarez', 'country_code': 'co'}
# <citipy.citipy.City object at 0x000001FC9399FD48>
# evensk ru
# {'city_name': 'evensk', 'country_code': 'ru'}
# <citipy.citipy.City object at 0x000001FC93E69E48>
# hilo us
# {'city_name': 'hilo', 'country_code': 'us'}
# <citipy.citipy.City object at 0x000001FC935D0F48>
# san policarpo ph
# {'city_name': 'san policarpo', 'country_code': 'ph'}
# <citipy.citipy.City object at 0x000001FC941F5848>
# cape town za
# {'city_name': 'cape town', 'country_code': 'za'}
# <citipy.citipy.City object at 0x000001FC933C74C8>
# mataura pf
# {'city_name': 'mataura', 'country_code': 'pf'}
# <citipy.citipy.City object at 0x000001FC927B36C8>
# puerto ayora ec
# {'city_name': 'puerto ayora', 'country_code': 'ec'}
# <citipy.citipy.City object at 0x000001FC93358088>
# bluff nz
# {'city_name': 'bluff', 'country_code': 'nz'}
# <citipy.citipy.City object at 0x000001FC92143688>
# mar del plata ar
# {'city_name': 'mar del plata', 'country_code': 'ar'}
# <citipy.citipy.City object at 0x000001FC93BF2348>
# kutum sd
# {'city_name': 'kutum', 'country_code': 'sd'}
# <citipy.citipy.City object at 0x000001FC924A2148>
# lebu cl
# {'city_name': 'lebu', 'country_code': 'cl'}
# <citipy.citipy.City object at 0x000001FC931CD908>
# guerrero negro mx
# {'city_name': 'guerrero negro', 'country_code': 'mx'}
# <citipy.citipy.City object at 0x000001FC941FC9C8>
# hermanus za
# {'city_name': 'hermanus', 'country_code': 'za'}
# <citipy.citipy.City object at 0x000001FC92DDB848>
# yarada in
# {'city_name': 'yarada', 'country_code': 'in'}
# <citipy.citipy.City object at 0x000001FC92176D08>
# carnarvon au
# {'city_name': 'carnarvon', 'country_code': 'au'}
# <citipy.citipy.City object at 0x000001FC931253C8>
# taolanaro mg
# {'city_name': 'taolanaro', 'country_code': 'mg'}
# <citipy.citipy.City object at 0x000001FC93191C88>
# cabo san lucas mx
# {'city_name': 'cabo san lucas', 'country_code': 'mx'}
# <citipy.citipy.City object at 0x000001FC93DB7348>
# barrow us
# {'city_name': 'barrow', 'country_code': 'us'}
# <citipy.citipy.City object at 0x000001FC941E9D48>
# saleaula ws
# {'city_name': 'saleaula', 'country_code': 'ws'}
# <citipy.citipy.City object at 0x000001FC93DB7708>
# fairbanks us
# {'city_name': 'fairbanks', 'country_code': 'us'}
# <citipy.citipy.City object at 0x000001FC9336FFC8>
# sur om
# {'city_name': 'sur', 'country_code': 'om'}
# <citipy.citipy.City object at 0x000001FC93341C88>
# snasa no
# {'city_name': 'snasa', 'country_code': 'no'}
# <citipy.citipy.City object at 0x000001FC92266BC8>
# acarau br
# {'city_name': 'acarau', 'country_code': 'br'}
# <citipy.citipy.City object at 0x000001FC941B5888>
# rawlins us
# {'city_name': 'rawlins', 'country_code': 'us'}
# <citipy.citipy.City object at 0x000001FC93DB7348>
# barrow us
# {'city_name': 'barrow', 'country_code': 'us'}
# <citipy.citipy.City object at 0x000001FC930ABBC8>
# butaritari ki
# {'city_name': 'butaritari', 'country_code': 'ki'}
# <citipy.citipy.City object at 0x000001FC927B36C8>
# puerto ayora ec
# {'city_name': 'puerto ayora', 'country_code': 'ec'}
# <citipy.citipy.City object at 0x000001FC93C69508>
# mango tg
# {'city_name': 'mango', 'country_code': 'tg'}
# <citipy.citipy.City object at 0x000001FC93C09508>
# jamestown sh
# {'city_name': 'jamestown', 'country_code': 'sh'}
# <citipy.citipy.City object at 0x000001FC93A9D248>
# novonukutskiy ru
# {'city_name': 'novonukutskiy', 'country_code': 'ru'}
# <citipy.citipy.City object at 0x000001FC930ABBC8>
# butaritari ki
# {'city_name': 'butaritari', 'country_code': 'ki'}
# <citipy.citipy.City object at 0x000001FC9398D108>
# dikson ru
# {'city_name': 'dikson', 'country_code': 'ru'}
# <citipy.citipy.City object at 0x000001FC930B7B08>
# kachiry kz
# {'city_name': 'kachiry', 'country_code': 'kz'}
# <citipy.citipy.City object at 0x000001FC93A8C288>
# nikolskoye ru
# {'city_name': 'nikolskoye', 'country_code': 'ru'}
# <citipy.citipy.City object at 0x000001FC93E69E48>
# hilo us
# {'city_name': 'hilo', 'country_code': 'us'}
# <citipy.citipy.City object at 0x000001FC92992F08>
# qaanaaq gl
# {'city_name': 'qaanaaq', 'country_code': 'gl'}
# <citipy.citipy.City object at 0x000001FC9398D108>
# dikson ru
# {'city_name': 'dikson', 'country_code': 'ru'}
# <citipy.citipy.City object at 0x000001FC9310F108>
# mizdah ly
# {'city_name': 'mizdah', 'country_code': 'ly'}
# <citipy.citipy.City object at 0x000001FC9243B148>
# thompson ca
# {'city_name': 'thompson', 'country_code': 'ca'}
# <citipy.citipy.City object at 0x000001FC939ECF08>
# khatanga ru
# {'city_name': 'khatanga', 'country_code': 'ru'}
# <citipy.citipy.City object at 0x000001FC933CD3C8>
# kieta pg
# {'city_name': 'kieta', 'country_code': 'pg'}
# <citipy.citipy.City object at 0x000001FC93CAD2C8>
# vaini to
# {'city_name': 'vaini', 'country_code': 'to'}
# <citipy.citipy.City object at 0x000001FC93AEDB08>
# provideniya ru
# {'city_name': 'provideniya', 'country_code': 'ru'}
# <citipy.citipy.City object at 0x000001FC92432488>
# sioux lookout ca
# {'city_name': 'sioux lookout', 'country_code': 'ca'}
# <citipy.citipy.City object at 0x000001FC941E4108>
# isangel vu
# {'city_name': 'isangel', 'country_code': 'vu'}
# <citipy.citipy.City object at 0x000001FC933C74C8>
# mataura pf
# {'city_name': 'mataura', 'country_code': 'pf'}
# <citipy.citipy.City object at 0x000001FC93A8C288>
# nikolskoye ru
# {'city_name': 'nikolskoye', 'country_code': 'ru'}
# <citipy.citipy.City object at 0x000001FC92B81148>
# bambanglipuro id
# {'city_name': 'bambanglipuro', 'country_code': 'id'}
# <citipy.citipy.City object at 0x000001FC9243B148>
# thompson ca
# {'city_name': 'thompson', 'country_code': 'ca'}
# <citipy.citipy.City object at 0x000001FC93223088>
# puerto madero mx
# {'city_name': 'puerto madero', 'country_code': 'mx'}
# <citipy.citipy.City object at 0x000001FC92B85108>
# bitung id
# {'city_name': 'bitung', 'country_code': 'id'}
# <citipy.citipy.City object at 0x000001FC941FC9C8>
# hermanus za
# {'city_name': 'hermanus', 'country_code': 'za'}
# <citipy.citipy.City object at 0x000001FC9399CEC8>
# egvekinot ru
# {'city_name': 'egvekinot', 'country_code': 'ru'}
# <citipy.citipy.City object at 0x000001FC924EDCC8>
# lasa cn
# {'city_name': 'lasa', 'country_code': 'cn'}
# <citipy.citipy.City object at 0x000001FC93AB6408>
# omsukchan ru
# {'city_name': 'omsukchan', 'country_code': 'ru'}
# <citipy.citipy.City object at 0x000001FC93E69E48>
# hilo us
# {'city_name': 'hilo', 'country_code': 'us'}
# <citipy.citipy.City object at 0x000001FC933C4448>
# atuona pf
# {'city_name': 'atuona', 'country_code': 'pf'}
# <citipy.citipy.City object at 0x000001FC926041C8>
# santa maria cv
# {'city_name': 'santa maria', 'country_code': 'cv'}
# <citipy.citipy.City object at 0x000001FC93C1BC08>
# barentsburg sj
# {'city_name': 'barentsburg', 'country_code': 'sj'}
# <citipy.citipy.City object at 0x000001FC93CAD2C8>
# vaini to
# {'city_name': 'vaini', 'country_code': 'to'}
# <citipy.citipy.City object at 0x000001FC941FC9C8>
# hermanus za
# {'city_name': 'hermanus', 'country_code': 'za'}
# <citipy.citipy.City object at 0x000001FC9315F988>
# grand gaube mu
# {'city_name': 'grand gaube', 'country_code': 'mu'}
# <citipy.citipy.City object at 0x000001FC939ECF08>
# khatanga ru
# {'city_name': 'khatanga', 'country_code': 'ru'}
# <citipy.citipy.City object at 0x000001FC933C82C8>
# rikitea pf
# {'city_name': 'rikitea', 'country_code': 'pf'}
# <citipy.citipy.City object at 0x000001FC923D9E48>
# bonavista ca
# {'city_name': 'bonavista', 'country_code': 'ca'}
# <citipy.citipy.City object at 0x000001FC941F5848>
# cape town za
# {'city_name': 'cape town', 'country_code': 'za'}
# <citipy.citipy.City object at 0x000001FC93CAD2C8>
# vaini to
# {'city_name': 'vaini', 'country_code': 'to'}
# <citipy.citipy.City object at 0x000001FC92985248>
# cayenne gf
# {'city_name': 'cayenne', 'country_code': 'gf'}
# <citipy.citipy.City object at 0x000001FC924A6248>
# punta arenas cl
# {'city_name': 'punta arenas', 'country_code': 'cl'}
# <citipy.citipy.City object at 0x000001FC93BEDD88>
# victoria sc
# {'city_name': 'victoria', 'country_code': 'sc'}
# <citipy.citipy.City object at 0x000001FC931604C8>
# mahebourg mu
# {'city_name': 'mahebourg', 'country_code': 'mu'}
# <citipy.citipy.City object at 0x000001FC922539C8>
# hamilton bm
# {'city_name': 'hamilton', 'country_code': 'bm'}
# <citipy.citipy.City object at 0x000001FC930D5248>
# harper lr
# {'city_name': 'harper', 'country_code': 'lr'}
# <citipy.citipy.City object at 0x000001FC924A6248>
# punta arenas cl
# {'city_name': 'punta arenas', 'country_code': 'cl'}
# <citipy.citipy.City object at 0x000001FC922539C8>
# hamilton bm
# {'city_name': 'hamilton', 'country_code': 'bm'}
# <citipy.citipy.City object at 0x000001FC92148FC8>
# ushuaia ar
# {'city_name': 'ushuaia', 'country_code': 'ar'}
# <citipy.citipy.City object at 0x000001FC92992C88>
# nuuk gl
# {'city_name': 'nuuk', 'country_code': 'gl'}
# <citipy.citipy.City object at 0x000001FC941F5848>
# cape town za
# {'city_name': 'cape town', 'country_code': 'za'}
# <citipy.citipy.City object at 0x000001FC9336FE88>
# salalah om
# {'city_name': 'salalah', 'country_code': 'om'}
# <citipy.citipy.City object at 0x000001FC9370D2C8>
# airai pw
# {'city_name': 'airai', 'country_code': 'pw'}
# <citipy.citipy.City object at 0x000001FC93B13488>
# sentyabrskiy ru
# {'city_name': 'sentyabrskiy', 'country_code': 'ru'}
# <citipy.citipy.City object at 0x000001FC92148FC8>
# ushuaia ar
# {'city_name': 'ushuaia', 'country_code': 'ar'}
# <citipy.citipy.City object at 0x000001FC93A8C288>
# nikolskoye ru
# {'city_name': 'nikolskoye', 'country_code': 'ru'}
# <citipy.citipy.City object at 0x000001FC93C45908>
# eyl so
# {'city_name': 'eyl', 'country_code': 'so'}
# <citipy.citipy.City object at 0x000001FC92171208>
# albany au
# {'city_name': 'albany', 'country_code': 'au'}
# <citipy.citipy.City object at 0x000001FC932B0088>
# vao nc
# {'city_name': 'vao', 'country_code': 'nc'}
# <citipy.citipy.City object at 0x000001FC933C74C8>
# mataura pf
# {'city_name': 'mataura', 'country_code': 'pf'}
# <citipy.citipy.City object at 0x000001FC9217E3C8>
# hobart au
# {'city_name': 'hobart', 'country_code': 'au'}
# <citipy.citipy.City object at 0x000001FC92CCF588>
# kavaratti in
# {'city_name': 'kavaratti', 'country_code': 'in'}
# <citipy.citipy.City object at 0x000001FC941F5848>
# cape town za
# {'city_name': 'cape town', 'country_code': 'za'}
# <citipy.citipy.City object at 0x000001FC92CAC1C8>
# janakpur road in
# {'city_name': 'janakpur road', 'country_code': 'in'}
# <citipy.citipy.City object at 0x000001FC9365D948>
# karachi pk
# {'city_name': 'karachi', 'country_code': 'pk'}
# <citipy.citipy.City object at 0x000001FC92499C08>
# avarua ck
# {'city_name': 'avarua', 'country_code': 'ck'}
# <citipy.citipy.City object at 0x000001FC93AEDB08>
# provideniya ru
# {'city_name': 'provideniya', 'country_code': 'ru'}
# <citipy.citipy.City object at 0x000001FC93952A88>
# belushya guba ru
# {'city_name': 'belushya guba', 'country_code': 'ru'}
# <citipy.citipy.City object at 0x000001FC93952A88>
# belushya guba ru
# {'city_name': 'belushya guba', 'country_code': 'ru'}
# <citipy.citipy.City object at 0x000001FC932A0D48>
# inhambane mz
# {'city_name': 'inhambane', 'country_code': 'mz'}
# <citipy.citipy.City object at 0x000001FC933C82C8>
# rikitea pf
# {'city_name': 'rikitea', 'country_code': 'pf'}
# <citipy.citipy.City object at 0x000001FC924A6248>
# punta arenas cl
# {'city_name': 'punta arenas', 'country_code': 'cl'}
# <citipy.citipy.City object at 0x000001FC933C82C8>
# rikitea pf
# {'city_name': 'rikitea', 'country_code': 'pf'}
# <citipy.citipy.City object at 0x000001FC92E5E848>
# marsala it
# {'city_name': 'marsala', 'country_code': 'it'}
# <citipy.citipy.City object at 0x000001FC92993448>
# tasiilaq gl
# {'city_name': 'tasiilaq', 'country_code': 'gl'}
# <citipy.citipy.City object at 0x000001FC92148FC8>
# ushuaia ar
# {'city_name': 'ushuaia', 'country_code': 'ar'}
# <citipy.citipy.City object at 0x000001FC9243B148>
# thompson ca
# {'city_name': 'thompson', 'country_code': 'ca'}
# <citipy.citipy.City object at 0x000001FC9217C488>
# geraldton au
# {'city_name': 'geraldton', 'country_code': 'au'}
# <citipy.citipy.City object at 0x000001FC924A6248>
# punta arenas cl
# {'city_name': 'punta arenas', 'country_code': 'cl'}
# <citipy.citipy.City object at 0x000001FC922262C8>
# djibo bf
# {'city_name': 'djibo', 'country_code': 'bf'}
# <citipy.citipy.City object at 0x000001FC923E61C8>
# clyde river ca
# {'city_name': 'clyde river', 'country_code': 'ca'}
# <citipy.citipy.City object at 0x000001FC924A6248>
# punta arenas cl
# {'city_name': 'punta arenas', 'country_code': 'cl'}
# <citipy.citipy.City object at 0x000001FC93C093C8>
# georgetown sh
# {'city_name': 'georgetown', 'country_code': 'sh'}
# <citipy.citipy.City object at 0x000001FC939312C8>
# amderma ru
# {'city_name': 'amderma', 'country_code': 'ru'}
# <citipy.citipy.City object at 0x000001FC92BB8D08>
# sungaipenuh id
# {'city_name': 'sungaipenuh', 'country_code': 'id'}
# <citipy.citipy.City object at 0x000001FC93CAD2C8>
# vaini to
# {'city_name': 'vaini', 'country_code': 'to'}
# <citipy.citipy.City object at 0x000001FC92147608>
# salta ar
# {'city_name': 'salta', 'country_code': 'ar'}
# <citipy.citipy.City object at 0x000001FC93DB7E88>
# nome us
# {'city_name': 'nome', 'country_code': 'us'}
# <citipy.citipy.City object at 0x000001FC931253C8>
# taolanaro mg
# {'city_name': 'taolanaro', 'country_code': 'mg'}
# <citipy.citipy.City object at 0x000001FC93DB7D48>
# kodiak us
# {'city_name': 'kodiak', 'country_code': 'us'}
# <citipy.citipy.City object at 0x000001FC93E69E48>
# hilo us
# {'city_name': 'hilo', 'country_code': 'us'}
# <citipy.citipy.City object at 0x000001FC93B7A0C8>
# tupik ru
# {'city_name': 'tupik', 'country_code': 'ru'}
# <citipy.citipy.City object at 0x000001FC93C73088>
# chumphon th
# {'city_name': 'chumphon', 'country_code': 'th'}
# <citipy.citipy.City object at 0x000001FC941F3E48>
# bredasdorp za
# {'city_name': 'bredasdorp', 'country_code': 'za'}
# <citipy.citipy.City object at 0x000001FC92171208>
# albany au
# {'city_name': 'albany', 'country_code': 'au'}
# <citipy.citipy.City object at 0x000001FC9249CF08>
# castro cl
# {'city_name': 'castro', 'country_code': 'cl'}
# <citipy.citipy.City object at 0x000001FC93E6A4C8>
# kapaa us
# {'city_name': 'kapaa', 'country_code': 'us'}
# <citipy.citipy.City object at 0x000001FC933A2C88>
# hualmay pe
# {'city_name': 'hualmay', 'country_code': 'pe'}
# <citipy.citipy.City object at 0x000001FC93982F48>
# chokurdakh ru
# {'city_name': 'chokurdakh', 'country_code': 'ru'}
# <citipy.citipy.City object at 0x000001FC92EEB948>
# kamaishi jp
# {'city_name': 'kamaishi', 'country_code': 'jp'}
# <citipy.citipy.City object at 0x000001FC92F23C08>
# shimoda jp
# {'city_name': 'shimoda', 'country_code': 'jp'}
# <citipy.citipy.City object at 0x000001FC923FCE48>
# iqaluit ca
# {'city_name': 'iqaluit', 'country_code': 'ca'}
# <citipy.citipy.City object at 0x000001FC92FA6A88>
# grand island us
# {'city_name': 'grand island', 'country_code': 'us'}
# <citipy.citipy.City object at 0x000001FC941F5848>
# cape town za
# {'city_name': 'cape town', 'country_code': 'za'}
# <citipy.citipy.City object at 0x000001FC924CCC88>
# dongsheng cn
# {'city_name': 'dongsheng', 'country_code': 'cn'}
# <citipy.citipy.City object at 0x000001FC93166F08>
# hithadhoo mv
# {'city_name': 'hithadhoo', 'country_code': 'mv'}
# <citipy.citipy.City object at 0x000001FC933A2C88>
# hualmay pe
# {'city_name': 'hualmay', 'country_code': 'pe'}
# <citipy.citipy.City object at 0x000001FC9235B3C8>
# porto belo br
# {'city_name': 'porto belo', 'country_code': 'br'}
# <citipy.citipy.City object at 0x000001FC933A4948>
# huarmey pe
# {'city_name': 'huarmey', 'country_code': 'pe'}
# <citipy.citipy.City object at 0x000001FC924A2148>
# lebu cl
# {'city_name': 'lebu', 'country_code': 'cl'}
# <citipy.citipy.City object at 0x000001FC92171208>
# albany au
# {'city_name': 'albany', 'country_code': 'au'}
# <citipy.citipy.City object at 0x000001FC92430CC8>
# shelburne ca
# {'city_name': 'shelburne', 'country_code': 'ca'}
# <citipy.citipy.City object at 0x000001FC9217EC88>
# karratha au
# {'city_name': 'karratha', 'country_code': 'au'}
# <citipy.citipy.City object at 0x000001FC933C82C8>
# rikitea pf
# {'city_name': 'rikitea', 'country_code': 'pf'}
# <citipy.citipy.City object at 0x000001FC9243BC88>
# torbay ca
# {'city_name': 'torbay', 'country_code': 'ca'}
# <citipy.citipy.City object at 0x000001FC933C4448>
# atuona pf
# {'city_name': 'atuona', 'country_code': 'pf'}
# <citipy.citipy.City object at 0x000001FC93191C88>
# cabo san lucas mx
# {'city_name': 'cabo san lucas', 'country_code': 'mx'}
# <citipy.citipy.City object at 0x000001FC932C2DC8>
# keffi ng
# {'city_name': 'keffi', 'country_code': 'ng'}
# <citipy.citipy.City object at 0x000001FC9316AA88>
# thinadhoo mv
# {'city_name': 'thinadhoo', 'country_code': 'mv'}
# <citipy.citipy.City object at 0x000001FC93717388>
# filadelfia py
# {'city_name': 'filadelfia', 'country_code': 'py'}
# <citipy.citipy.City object at 0x000001FC93166F08>
# hithadhoo mv
# {'city_name': 'hithadhoo', 'country_code': 'mv'}
# <citipy.citipy.City object at 0x000001FC933C4448>
# atuona pf
# {'city_name': 'atuona', 'country_code': 'pf'}
# <citipy.citipy.City object at 0x000001FC92937388>
# kirkwall gb
# {'city_name': 'kirkwall', 'country_code': 'gb'}
# <citipy.citipy.City object at 0x000001FC9335C048>
# hokitika nz
# {'city_name': 'hokitika', 'country_code': 'nz'}
# <citipy.citipy.City object at 0x000001FC92E00F48>
# vestmannaeyjar is
# {'city_name': 'vestmannaeyjar', 'country_code': 'is'}
# <citipy.citipy.City object at 0x000001FC93B0D6C8>
# saskylakh ru
# {'city_name': 'saskylakh', 'country_code': 'ru'}
# <citipy.citipy.City object at 0x000001FC924A2148>
# lebu cl
# {'city_name': 'lebu', 'country_code': 'cl'}
# <citipy.citipy.City object at 0x000001FC932B0308>
# we nc
# {'city_name': 'we', 'country_code': 'nc'}
# <citipy.citipy.City object at 0x000001FC930ABBC8>
# butaritari ki
# {'city_name': 'butaritari', 'country_code': 'ki'}
# <citipy.citipy.City object at 0x000001FC93CAD2C8>
# vaini to
# {'city_name': 'vaini', 'country_code': 'to'}
# <citipy.citipy.City object at 0x000001FC941F3E48>
# bredasdorp za
# {'city_name': 'bredasdorp', 'country_code': 'za'}
# <citipy.citipy.City object at 0x000001FC941FC9C8>
# hermanus za
# {'city_name': 'hermanus', 'country_code': 'za'}
# <citipy.citipy.City object at 0x000001FC92B8FEC8>
# gondanglegi id
# {'city_name': 'gondanglegi', 'country_code': 'id'}
# <citipy.citipy.City object at 0x000001FC939809C8>
# cherskiy ru
# {'city_name': 'cherskiy', 'country_code': 'ru'}
# <citipy.citipy.City object at 0x000001FC927B36C8>
# puerto ayora ec
# {'city_name': 'puerto ayora', 'country_code': 'ec'}
# <citipy.citipy.City object at 0x000001FC92184A08>
# mount gambier au
# {'city_name': 'mount gambier', 'country_code': 'au'}
# <citipy.citipy.City object at 0x000001FC92985D88>
# sinnamary gf
# {'city_name': 'sinnamary', 'country_code': 'gf'}
# <citipy.citipy.City object at 0x000001FC924A6248>
# punta arenas cl
# {'city_name': 'punta arenas', 'country_code': 'cl'}
# <citipy.citipy.City object at 0x000001FC92253B08>
# saint george bm
# {'city_name': 'saint george', 'country_code': 'bm'}
# <citipy.citipy.City object at 0x000001FC936E3C48>
# lagoa pt
# {'city_name': 'lagoa', 'country_code': 'pt'}
# <citipy.citipy.City object at 0x000001FC930CA9C8>
# beruwala lk
# {'city_name': 'beruwala', 'country_code': 'lk'}
# <citipy.citipy.City object at 0x000001FC930ABBC8>
# butaritari ki
# {'city_name': 'butaritari', 'country_code': 'ki'}
# <citipy.citipy.City object at 0x000001FC933CB348>
# angoram pg
# {'city_name': 'angoram', 'country_code': 'pg'}
# <citipy.citipy.City object at 0x000001FC941E4108>
# isangel vu
# {'city_name': 'isangel', 'country_code': 'vu'}
# <citipy.citipy.City object at 0x000001FC9398D108>
# dikson ru
# {'city_name': 'dikson', 'country_code': 'ru'}
# <citipy.citipy.City object at 0x000001FC93C093C8>
# georgetown sh
# {'city_name': 'georgetown', 'country_code': 'sh'}
# <citipy.citipy.City object at 0x000001FC927DDFC8>
# ginda er
# {'city_name': 'ginda', 'country_code': 'er'}
# <citipy.citipy.City object at 0x000001FC933CD288>
# kerema pg
# {'city_name': 'kerema', 'country_code': 'pg'}
# <citipy.citipy.City object at 0x000001FC923F0E48>
# flin flon ca
# {'city_name': 'flin flon', 'country_code': 'ca'}
# <citipy.citipy.City object at 0x000001FC92143688>
# mar del plata ar
# {'city_name': 'mar del plata', 'country_code': 'ar'}
# <citipy.citipy.City object at 0x000001FC941E4D88>
# vaitupu wf
# {'city_name': 'vaitupu', 'country_code': 'wf'}
# <citipy.citipy.City object at 0x000001FC93EA5688>
# davenport us
# {'city_name': 'davenport', 'country_code': 'us'}
# <citipy.citipy.City object at 0x000001FC93311388>
# andenes no
# {'city_name': 'andenes', 'country_code': 'no'}
# <citipy.citipy.City object at 0x000001FC933C74C8>
# mataura pf
# {'city_name': 'mataura', 'country_code': 'pf'}
# <citipy.citipy.City object at 0x000001FC931258C8>
# tsihombe mg
# {'city_name': 'tsihombe', 'country_code': 'mg'}
# <citipy.citipy.City object at 0x000001FC92143688>
# mar del plata ar
# {'city_name': 'mar del plata', 'country_code': 'ar'}
# <citipy.citipy.City object at 0x000001FC93E6A4C8>
# kapaa us
# {'city_name': 'kapaa', 'country_code': 'us'}
# <citipy.citipy.City object at 0x000001FC92171208>
# albany au
# {'city_name': 'albany', 'country_code': 'au'}
# <citipy.citipy.City object at 0x000001FC93C1BC08>
# barentsburg sj
# {'city_name': 'barentsburg', 'country_code': 'sj'}
# <citipy.citipy.City object at 0x000001FC932A8E08>
# walvis bay na
# {'city_name': 'walvis bay', 'country_code': 'na'}
# <citipy.citipy.City object at 0x000001FC92339088>
# olinda br
# {'city_name': 'olinda', 'country_code': 'br'}
# <citipy.citipy.City object at 0x000001FC931253C8>
# taolanaro mg
# {'city_name': 'taolanaro', 'country_code': 'mg'}
# <citipy.citipy.City object at 0x000001FC93BF02C8>
# bara sd
# {'city_name': 'bara', 'country_code': 'sd'}
# <citipy.citipy.City object at 0x000001FC942060C8>
# port alfred za
# {'city_name': 'port alfred', 'country_code': 'za'}
# <citipy.citipy.City object at 0x000001FC924477C8>
# yellowknife ca
# {'city_name': 'yellowknife', 'country_code': 'ca'}
# <citipy.citipy.City object at 0x000001FC93B0D6C8>
# saskylakh ru
# {'city_name': 'saskylakh', 'country_code': 'ru'}
# <citipy.citipy.City object at 0x000001FC93952A88>
# belushya guba ru
# {'city_name': 'belushya guba', 'country_code': 'ru'}
# <citipy.citipy.City object at 0x000001FC931253C8>
# taolanaro mg
# {'city_name': 'taolanaro', 'country_code': 'mg'}
# <citipy.citipy.City object at 0x000001FC92BF9A88>
# amguri in
# {'city_name': 'amguri', 'country_code': 'in'}
# <citipy.citipy.City object at 0x000001FC933C4448>
# atuona pf
# {'city_name': 'atuona', 'country_code': 'pf'}
# <citipy.citipy.City object at 0x000001FC92993588>
# upernavik gl
# {'city_name': 'upernavik', 'country_code': 'gl'}
# <citipy.citipy.City object at 0x000001FC92181448>
# kununurra au
# {'city_name': 'kununurra', 'country_code': 'au'}
# <citipy.citipy.City object at 0x000001FC92499C08>
# avarua ck
# {'city_name': 'avarua', 'country_code': 'ck'}
# <citipy.citipy.City object at 0x000001FC939ECF08>
# khatanga ru
# {'city_name': 'khatanga', 'country_code': 'ru'}
# <citipy.citipy.City object at 0x000001FC9335C548>
# kaitangata nz
# {'city_name': 'kaitangata', 'country_code': 'nz'}
# <citipy.citipy.City object at 0x000001FC92148FC8>
# ushuaia ar
# {'city_name': 'ushuaia', 'country_code': 'ar'}
# <citipy.citipy.City object at 0x000001FC9372C448>
# saint-philippe re
# {'city_name': 'saint-philippe', 'country_code': 're'}
# <citipy.citipy.City object at 0x000001FC933A2508>
# el alto pe
# {'city_name': 'el alto', 'country_code': 'pe'}
# <citipy.citipy.City object at 0x000001FC930ABBC8>
# butaritari ki
# {'city_name': 'butaritari', 'country_code': 'ki'}
# <citipy.citipy.City object at 0x000001FC92148FC8>
# ushuaia ar
# {'city_name': 'ushuaia', 'country_code': 'ar'}
# <citipy.citipy.City object at 0x000001FC92451908>
# mweka cd
# {'city_name': 'mweka', 'country_code': 'cd'}
# <citipy.citipy.City object at 0x000001FC93188F48>
# atliaca mx
# {'city_name': 'atliaca', 'country_code': 'mx'}
# <citipy.citipy.City object at 0x000001FC92148288>
# san rafael ar
# {'city_name': 'san rafael', 'country_code': 'ar'}
# <citipy.citipy.City object at 0x000001FC92186948>
# new norfolk au
# {'city_name': 'new norfolk', 'country_code': 'au'}
# <citipy.citipy.City object at 0x000001FC933CDDC8>
# lorengau pg
# {'city_name': 'lorengau', 'country_code': 'pg'}
# <citipy.citipy.City object at 0x000001FC92148FC8>
# ushuaia ar
# {'city_name': 'ushuaia', 'country_code': 'ar'}
# <citipy.citipy.City object at 0x000001FC93B7A348>
# tura ru
# {'city_name': 'tura', 'country_code': 'ru'}
# <citipy.citipy.City object at 0x000001FC92BA8688>
# palabuhanratu id
# {'city_name': 'palabuhanratu', 'country_code': 'id'}
# <citipy.citipy.City object at 0x000001FC933B3648>
# pisco pe
# {'city_name': 'pisco', 'country_code': 'pe'}
# <citipy.citipy.City object at 0x000001FC931253C8>
# taolanaro mg
# {'city_name': 'taolanaro', 'country_code': 'mg'}
# <citipy.citipy.City object at 0x000001FC923FAA08>
# high level ca
# {'city_name': 'high level', 'country_code': 'ca'}
# <citipy.citipy.City object at 0x000001FC93E6A108>
# kahului us
# {'city_name': 'kahului', 'country_code': 'us'}
# <citipy.citipy.City object at 0x000001FC9399FD48>
# evensk ru
# {'city_name': 'evensk', 'country_code': 'ru'}
# <citipy.citipy.City object at 0x000001FC930ABE48>
# rawannawi ki
# {'city_name': 'rawannawi', 'country_code': 'ki'}
# <citipy.citipy.City object at 0x000001FC92189A48>
# port lincoln au
# {'city_name': 'port lincoln', 'country_code': 'au'}
# <citipy.citipy.City object at 0x000001FC92186948>
# new norfolk au
# {'city_name': 'new norfolk', 'country_code': 'au'}
# <citipy.citipy.City object at 0x000001FC933C82C8>
# rikitea pf
# {'city_name': 'rikitea', 'country_code': 'pf'}
# <citipy.citipy.City object at 0x000001FC923FCE48>
# iqaluit ca
# {'city_name': 'iqaluit', 'country_code': 'ca'}
# <citipy.citipy.City object at 0x000001FC941F7C88>
# east london za
# {'city_name': 'east london', 'country_code': 'za'}
# <citipy.citipy.City object at 0x000001FC930AB948>
# bairiki ki
# {'city_name': 'bairiki', 'country_code': 'ki'}
# <citipy.citipy.City object at 0x000001FC9335C548>
# kaitangata nz
# {'city_name': 'kaitangata', 'country_code': 'nz'}
# <citipy.citipy.City object at 0x000001FC933C82C8>
# rikitea pf
# {'city_name': 'rikitea', 'country_code': 'pf'}
# <citipy.citipy.City object at 0x000001FC92173C88>
# broken hill au
# {'city_name': 'broken hill', 'country_code': 'au'}
# <citipy.citipy.City object at 0x000001FC92E81A48>
# polignano a mare it
# {'city_name': 'polignano a mare', 'country_code': 'it'}
# <citipy.citipy.City object at 0x000001FC941B7548>
# chuy uy
# {'city_name': 'chuy', 'country_code': 'uy'}
# <citipy.citipy.City object at 0x000001FC93E69D08>
# ewa beach us
# {'city_name': 'ewa beach', 'country_code': 'us'}
# <citipy.citipy.City object at 0x000001FC924A2148>
# lebu cl
# {'city_name': 'lebu', 'country_code': 'cl'}
# <citipy.citipy.City object at 0x000001FC933C74C8>
# mataura pf
# {'city_name': 'mataura', 'country_code': 'pf'}
# <citipy.citipy.City object at 0x000001FC93A7B7C8>
# muzhi ru
# {'city_name': 'muzhi', 'country_code': 'ru'}
# <citipy.citipy.City object at 0x000001FC93B18CC8>
# severo-kurilsk ru
# {'city_name': 'severo-kurilsk', 'country_code': 'ru'}
# <citipy.citipy.City object at 0x000001FC92257208>
# chimore bo
# {'city_name': 'chimore', 'country_code': 'bo'}
# <citipy.citipy.City object at 0x000001FC924A6248>
# punta arenas cl
# {'city_name': 'punta arenas', 'country_code': 'cl'}
# <citipy.citipy.City object at 0x000001FC93BECD08>
# sakakah sa
# {'city_name': 'sakakah', 'country_code': 'sa'}
# <citipy.citipy.City object at 0x000001FC92B7ECC8>
# amahai id
# {'city_name': 'amahai', 'country_code': 'id'}
# <citipy.citipy.City object at 0x000001FC922E8808>
# ilhabela br
# {'city_name': 'ilhabela', 'country_code': 'br'}
# <citipy.citipy.City object at 0x000001FC921C2088>
# bathsheba bb
# {'city_name': 'bathsheba', 'country_code': 'bb'}
# <citipy.citipy.City object at 0x000001FC931258C8>
# tsihombe mg
# {'city_name': 'tsihombe', 'country_code': 'mg'}
# <citipy.citipy.City object at 0x000001FC92176588>
# busselton au
# {'city_name': 'busselton', 'country_code': 'au'}
# <citipy.citipy.City object at 0x000001FC933C82C8>
# rikitea pf
# {'city_name': 'rikitea', 'country_code': 'pf'}
# <citipy.citipy.City object at 0x000001FC933C74C8>
# mataura pf
# {'city_name': 'mataura', 'country_code': 'pf'}
# <citipy.citipy.City object at 0x000001FC936E3608>
# horta pt
# {'city_name': 'horta', 'country_code': 'pt'}
# <citipy.citipy.City object at 0x000001FC933C74C8>
# mataura pf
# {'city_name': 'mataura', 'country_code': 'pf'}
# <citipy.citipy.City object at 0x000001FC93C09508>
# jamestown sh
# {'city_name': 'jamestown', 'country_code': 'sh'}
# <citipy.citipy.City object at 0x000001FC924210C8>
# prince george ca
# {'city_name': 'prince george', 'country_code': 'ca'}
# <citipy.citipy.City object at 0x000001FC93E6A4C8>
# kapaa us
# {'city_name': 'kapaa', 'country_code': 'us'}
# <citipy.citipy.City object at 0x000001FC94204948>
# phalaborwa za
# {'city_name': 'phalaborwa', 'country_code': 'za'}
# <citipy.citipy.City object at 0x000001FC932B0BC8>
# bilma ne
# {'city_name': 'bilma', 'country_code': 'ne'}
# <citipy.citipy.City object at 0x000001FC92186D08>
# nhulunbuy au
# {'city_name': 'nhulunbuy', 'country_code': 'au'}
# <citipy.citipy.City object at 0x000001FC92148FC8>
# ushuaia ar
# {'city_name': 'ushuaia', 'country_code': 'ar'}
# <citipy.citipy.City object at 0x000001FC933C74C8>
# mataura pf
# {'city_name': 'mataura', 'country_code': 'pf'}
# <citipy.citipy.City object at 0x000001FC941F3E48>
# bredasdorp za
# {'city_name': 'bredasdorp', 'country_code': 'za'}
# <citipy.citipy.City object at 0x000001FC93CAD2C8>
# vaini to
# {'city_name': 'vaini', 'country_code': 'to'}
# <citipy.citipy.City object at 0x000001FC92148FC8>
# ushuaia ar
# {'city_name': 'ushuaia', 'country_code': 'ar'}
# <citipy.citipy.City object at 0x000001FC92992788>
# kangaatsiaq gl
# {'city_name': 'kangaatsiaq', 'country_code': 'gl'}
# <citipy.citipy.City object at 0x000001FC93CAD2C8>
# vaini to
# {'city_name': 'vaini', 'country_code': 'to'}
# <citipy.citipy.City object at 0x000001FC935D0F48>
# san policarpo ph
# {'city_name': 'san policarpo', 'country_code': 'ph'}
# <citipy.citipy.City object at 0x000001FC92937388>
# kirkwall gb
# {'city_name': 'kirkwall', 'country_code': 'gb'}
# <citipy.citipy.City object at 0x000001FC93CAD2C8>
# vaini to
# {'city_name': 'vaini', 'country_code': 'to'}
# <citipy.citipy.City object at 0x000001FC93DB7348>
# barrow us
# {'city_name': 'barrow', 'country_code': 'us'}
# <citipy.citipy.City object at 0x000001FC93138A48>
# araouane ml
# {'city_name': 'araouane', 'country_code': 'ml'}
# <citipy.citipy.City object at 0x000001FC92F2E988>
# takehara jp
# {'city_name': 'takehara', 'country_code': 'jp'}
# <citipy.citipy.City object at 0x000001FC9227E7C8>
# arraial do cabo br
# {'city_name': 'arraial do cabo', 'country_code': 'br'}
# <citipy.citipy.City object at 0x000001FC933C4448>
# atuona pf
# {'city_name': 'atuona', 'country_code': 'pf'}
# <citipy.citipy.City object at 0x000001FC93368588>
# te anau nz
# {'city_name': 'te anau', 'country_code': 'nz'}
# <citipy.citipy.City object at 0x000001FC928451C8>
# kajaani fi
# {'city_name': 'kajaani', 'country_code': 'fi'}
# <citipy.citipy.City object at 0x000001FC924A6248>
# punta arenas cl
# {'city_name': 'punta arenas', 'country_code': 'cl'}
# <citipy.citipy.City object at 0x000001FC936D4988>
# camacha pt
# {'city_name': 'camacha', 'country_code': 'pt'}
# <citipy.citipy.City object at 0x000001FC941F3E48>
# bredasdorp za
# {'city_name': 'bredasdorp', 'country_code': 'za'}
# <citipy.citipy.City object at 0x000001FC92B81288>
# banda aceh id
# {'city_name': 'banda aceh', 'country_code': 'id'}
# <citipy.citipy.City object at 0x000001FC92499C08>
# avarua ck
# {'city_name': 'avarua', 'country_code': 'ck'}
# <citipy.citipy.City object at 0x000001FC93E6A4C8>
# kapaa us
# {'city_name': 'kapaa', 'country_code': 'us'}
# <citipy.citipy.City object at 0x000001FC92BB99C8>
# tanete id
# {'city_name': 'tanete', 'country_code': 'id'}
# <citipy.citipy.City object at 0x000001FC933C82C8>
# rikitea pf
# {'city_name': 'rikitea', 'country_code': 'pf'}
# <citipy.citipy.City object at 0x000001FC942060C8>
# port alfred za
# {'city_name': 'port alfred', 'country_code': 'za'}
# <citipy.citipy.City object at 0x000001FC93C76C08>
# kathu th
# {'city_name': 'kathu', 'country_code': 'th'}
# <citipy.citipy.City object at 0x000001FC93708DC8>
# vila franca do campo pt
# {'city_name': 'vila franca do campo', 'country_code': 'pt'}
# <citipy.citipy.City object at 0x000001FC92499C08>
# avarua ck
# {'city_name': 'avarua', 'country_code': 'ck'}
# <citipy.citipy.City object at 0x000001FC9372AF08>
# saint-joseph re
# {'city_name': 'saint-joseph', 'country_code': 're'}
# <citipy.citipy.City object at 0x000001FC92993588>
# upernavik gl
# {'city_name': 'upernavik', 'country_code': 'gl'}
# <citipy.citipy.City object at 0x000001FC9398D108>
# dikson ru
# {'city_name': 'dikson', 'country_code': 'ru'}
# <citipy.citipy.City object at 0x000001FC92604308>
# sao filipe cv
# {'city_name': 'sao filipe', 'country_code': 'cv'}
# <citipy.citipy.City object at 0x000001FC931258C8>
# tsihombe mg
# {'city_name': 'tsihombe', 'country_code': 'mg'}
# <citipy.citipy.City object at 0x000001FC92993448>
# tasiilaq gl
# {'city_name': 'tasiilaq', 'country_code': 'gl'}
# <citipy.citipy.City object at 0x000001FC937197C8>
# itape py
# {'city_name': 'itape', 'country_code': 'py'}
# <citipy.citipy.City object at 0x000001FC93DB7488>
# bethel us
# {'city_name': 'bethel', 'country_code': 'us'}
# <citipy.citipy.City object at 0x000001FC9217E3C8>
# hobart au
# {'city_name': 'hobart', 'country_code': 'au'}
# <citipy.citipy.City object at 0x000001FC922B0808>
# carutapera br
# {'city_name': 'carutapera', 'country_code': 'br'}
# <citipy.citipy.City object at 0x000001FC92992B48>
# narsaq gl
# {'city_name': 'narsaq', 'country_code': 'gl'}
# <citipy.citipy.City object at 0x000001FC941BC208>
# rocha uy
# {'city_name': 'rocha', 'country_code': 'uy'}
# <citipy.citipy.City object at 0x000001FC93358088>
# bluff nz
# {'city_name': 'bluff', 'country_code': 'nz'}
# <citipy.citipy.City object at 0x000001FC92148FC8>
# ushuaia ar
# {'city_name': 'ushuaia', 'country_code': 'ar'}
# <citipy.citipy.City object at 0x000001FC93E6A4C8>
# kapaa us
# {'city_name': 'kapaa', 'country_code': 'us'}
# <citipy.citipy.City object at 0x000001FC92148FC8>
# ushuaia ar
# {'city_name': 'ushuaia', 'country_code': 'ar'}
# <citipy.citipy.City object at 0x000001FC933C82C8>
# rikitea pf
# {'city_name': 'rikitea', 'country_code': 'pf'}
# <citipy.citipy.City object at 0x000001FC941F3E48>
# bredasdorp za
# {'city_name': 'bredasdorp', 'country_code': 'za'}
# <citipy.citipy.City object at 0x000001FC92443F88>
# whitehorse ca
# {'city_name': 'whitehorse', 'country_code': 'ca'}
# <citipy.citipy.City object at 0x000001FC92176588>
# busselton au
# {'city_name': 'busselton', 'country_code': 'au'}
# <citipy.citipy.City object at 0x000001FC93E69E48>
# hilo us
# {'city_name': 'hilo', 'country_code': 'us'}
# <citipy.citipy.City object at 0x000001FC933C82C8>
# rikitea pf
# {'city_name': 'rikitea', 'country_code': 'pf'}
# <citipy.citipy.City object at 0x000001FC933C74C8>
# mataura pf
# {'city_name': 'mataura', 'country_code': 'pf'}
# <citipy.citipy.City object at 0x000001FC92499D48>
# ancud cl
# {'city_name': 'ancud', 'country_code': 'cl'}
# <citipy.citipy.City object at 0x000001FC92148988>
# tandil ar
# {'city_name': 'tandil', 'country_code': 'ar'}
# <citipy.citipy.City object at 0x000001FC930B9188>
# kazalinsk kz
# {'city_name': 'kazalinsk', 'country_code': 'kz'}
# <citipy.citipy.City object at 0x000001FC933C82C8>
# rikitea pf
# {'city_name': 'rikitea', 'country_code': 'pf'}
# <citipy.citipy.City object at 0x000001FC9217E3C8>
# hobart au
# {'city_name': 'hobart', 'country_code': 'au'}
# <citipy.citipy.City object at 0x000001FC93CAD2C8>
# vaini to
# {'city_name': 'vaini', 'country_code': 'to'}
# <citipy.citipy.City object at 0x000001FC93358088>
# bluff nz
# {'city_name': 'bluff', 'country_code': 'nz'}
# <citipy.citipy.City object at 0x000001FC941F5848>
# cape town za
# {'city_name': 'cape town', 'country_code': 'za'}
# <citipy.citipy.City object at 0x000001FC92171208>
# albany au
# {'city_name': 'albany', 'country_code': 'au'}
# <citipy.citipy.City object at 0x000001FC93C45CC8>
# hobyo so
# {'city_name': 'hobyo', 'country_code': 'so'}
# <citipy.citipy.City object at 0x000001FC92171208>
# albany au
# {'city_name': 'albany', 'country_code': 'au'}
# <citipy.citipy.City object at 0x000001FC92171208>
# albany au
# {'city_name': 'albany', 'country_code': 'au'}
# <citipy.citipy.City object at 0x000001FC93952A88>
# belushya guba ru
# {'city_name': 'belushya guba', 'country_code': 'ru'}
# <citipy.citipy.City object at 0x000001FC92432488>
# sioux lookout ca
# {'city_name': 'sioux lookout', 'country_code': 'ca'}
# <citipy.citipy.City object at 0x000001FC936E3C48>
# lagoa pt
# {'city_name': 'lagoa', 'country_code': 'pt'}
# <citipy.citipy.City object at 0x000001FC933CDDC8>
# lorengau pg
# {'city_name': 'lorengau', 'country_code': 'pg'}
# <citipy.citipy.City object at 0x000001FC933C82C8>
# rikitea pf
# {'city_name': 'rikitea', 'country_code': 'pf'}
# <citipy.citipy.City object at 0x000001FC92143688>
# mar del plata ar
# {'city_name': 'mar del plata', 'country_code': 'ar'}
# <citipy.citipy.City object at 0x000001FC93E6A4C8>
# kapaa us
# {'city_name': 'kapaa', 'country_code': 'us'}
# <citipy.citipy.City object at 0x000001FC927B8148>
# santo domingo ec
# {'city_name': 'santo domingo', 'country_code': 'ec'}
# <citipy.citipy.City object at 0x000001FC92992648>
# ilulissat gl
# {'city_name': 'ilulissat', 'country_code': 'gl'}
# <citipy.citipy.City object at 0x000001FC93CAD2C8>
# vaini to
# {'city_name': 'vaini', 'country_code': 'to'}
# <citipy.citipy.City object at 0x000001FC933C82C8>
# rikitea pf
# {'city_name': 'rikitea', 'country_code': 'pf'}
# <citipy.citipy.City object at 0x000001FC92148FC8>
# ushuaia ar
# {'city_name': 'ushuaia', 'country_code': 'ar'}
# <citipy.citipy.City object at 0x000001FC93656948>
# hunza pk
# {'city_name': 'hunza', 'country_code': 'pk'}
# <citipy.citipy.City object at 0x000001FC939D7908>
# kamensk-uralskiy ru
# {'city_name': 'kamensk-uralskiy', 'country_code': 'ru'}
# <citipy.citipy.City object at 0x000001FC939554C8>
# berdigestyakh ru
# {'city_name': 'berdigestyakh', 'country_code': 'ru'}
# <citipy.citipy.City object at 0x000001FC92186E48>
# northam au
# {'city_name': 'northam', 'country_code': 'au'}
# <citipy.citipy.City object at 0x000001FC936F5448>
# ponta delgada pt
# {'city_name': 'ponta delgada', 'country_code': 'pt'}
# <citipy.citipy.City object at 0x000001FC941FC9C8>
# hermanus za
# {'city_name': 'hermanus', 'country_code': 'za'}
# <citipy.citipy.City object at 0x000001FC92499C08>
# avarua ck
# {'city_name': 'avarua', 'country_code': 'ck'}
# <citipy.citipy.City object at 0x000001FC93B00D48>
# russkaya polyana ru
# {'city_name': 'russkaya polyana', 'country_code': 'ru'}
# <citipy.citipy.City object at 0x000001FC93358088>
# bluff nz
# {'city_name': 'bluff', 'country_code': 'nz'}
# <citipy.citipy.City object at 0x000001FC93157B48>
# bambous virieux mu
# {'city_name': 'bambous virieux', 'country_code': 'mu'}
# <citipy.citipy.City object at 0x000001FC92148FC8>
# ushuaia ar
# {'city_name': 'ushuaia', 'country_code': 'ar'}
# <citipy.citipy.City object at 0x000001FC924DAAC8>
# hongan cn
# {'city_name': 'hongan', 'country_code': 'cn'}
# <citipy.citipy.City object at 0x000001FC923D2F48>
# attawapiskat ca
# {'city_name': 'attawapiskat', 'country_code': 'ca'}
# <citipy.citipy.City object at 0x000001FC93C09508>
# jamestown sh
# {'city_name': 'jamestown', 'country_code': 'sh'}
# <citipy.citipy.City object at 0x000001FC92451188>
# matadi cd
# {'city_name': 'matadi', 'country_code': 'cd'}
# <citipy.citipy.City object at 0x000001FC933C4448>
# atuona pf
# {'city_name': 'atuona', 'country_code': 'pf'}
# <citipy.citipy.City object at 0x000001FC941E9D48>
# saleaula ws
# {'city_name': 'saleaula', 'country_code': 'ws'}
# <citipy.citipy.City object at 0x000001FC92176588>
# busselton au
# {'city_name': 'busselton', 'country_code': 'au'}
# <citipy.citipy.City object at 0x000001FC927B36C8>
# puerto ayora ec
# {'city_name': 'puerto ayora', 'country_code': 'ec'}
# <citipy.citipy.City object at 0x000001FC92407F88>
# louisbourg ca
# {'city_name': 'louisbourg', 'country_code': 'ca'}
# <citipy.citipy.City object at 0x000001FC93926B48>
# aksarka ru
# {'city_name': 'aksarka', 'country_code': 'ru'}
# <citipy.citipy.City object at 0x000001FC924A6248>
# punta arenas cl
# {'city_name': 'punta arenas', 'country_code': 'cl'}
# <citipy.citipy.City object at 0x000001FC942060C8>
# port alfred za
# {'city_name': 'port alfred', 'country_code': 'za'}
# <citipy.citipy.City object at 0x000001FC941B7548>
# chuy uy
# {'city_name': 'chuy', 'country_code': 'uy'}
# <citipy.citipy.City object at 0x000001FC9336FFC8>
# sur om
# {'city_name': 'sur', 'country_code': 'om'}
# <citipy.citipy.City object at 0x000001FC924A6248>
# punta arenas cl
# {'city_name': 'punta arenas', 'country_code': 'cl'}
# <citipy.citipy.City object at 0x000001FC93C09508>
# jamestown sh
# {'city_name': 'jamestown', 'country_code': 'sh'}
# <citipy.citipy.City object at 0x000001FC93948288>
# barguzin ru
# {'city_name': 'barguzin', 'country_code': 'ru'}
# <citipy.citipy.City object at 0x000001FC93CAD2C8>
# vaini to
# {'city_name': 'vaini', 'country_code': 'to'}
# <citipy.citipy.City object at 0x000001FC930BF948>
# tasbuget kz
# {'city_name': 'tasbuget', 'country_code': 'kz'}
# <citipy.citipy.City object at 0x000001FC92ED8D08>
# hasaki jp
# {'city_name': 'hasaki', 'country_code': 'jp'}
# <citipy.citipy.City object at 0x000001FC93DB7988>
# juneau us
# {'city_name': 'juneau', 'country_code': 'us'}
# <citipy.citipy.City object at 0x000001FC92ED8D08>
# hasaki jp
# {'city_name': 'hasaki', 'country_code': 'jp'}
# <citipy.citipy.City object at 0x000001FC93DB7488>
# bethel us
# {'city_name': 'bethel', 'country_code': 'us'}
# <citipy.citipy.City object at 0x000001FC941FC608>
# heilbron za
# {'city_name': 'heilbron', 'country_code': 'za'}
# <citipy.citipy.City object at 0x000001FC930ABBC8>
# butaritari ki
# {'city_name': 'butaritari', 'country_code': 'ki'}
# <citipy.citipy.City object at 0x000001FC941F5848>
# cape town za
# {'city_name': 'cape town', 'country_code': 'za'}
# <citipy.citipy.City object at 0x000001FC933CD148>
# kavieng pg
# {'city_name': 'kavieng', 'country_code': 'pg'}
# <citipy.citipy.City object at 0x000001FC92176588>
# busselton au
# {'city_name': 'busselton', 'country_code': 'au'}
# <citipy.citipy.City object at 0x000001FC93BB4308>
# vostok ru
# {'city_name': 'vostok', 'country_code': 'ru'}
# <citipy.citipy.City object at 0x000001FC92148FC8>
# ushuaia ar
# {'city_name': 'ushuaia', 'country_code': 'ar'}
# <citipy.citipy.City object at 0x000001FC93CAD2C8>
# vaini to
# {'city_name': 'vaini', 'country_code': 'to'}
# <citipy.citipy.City object at 0x000001FC933C82C8>
# rikitea pf
# {'city_name': 'rikitea', 'country_code': 'pf'}
# <citipy.citipy.City object at 0x000001FC93C1BC08>
# barentsburg sj
# {'city_name': 'barentsburg', 'country_code': 'sj'}
# <citipy.citipy.City object at 0x000001FC92148FC8>
# ushuaia ar
# {'city_name': 'ushuaia', 'country_code': 'ar'}
# <citipy.citipy.City object at 0x000001FC924A2148>
# lebu cl
# {'city_name': 'lebu', 'country_code': 'cl'}
# <citipy.citipy.City object at 0x000001FC92176588>
# busselton au
# {'city_name': 'busselton', 'country_code': 'au'}
# <citipy.citipy.City object at 0x000001FC92189B88>
# port macquarie au
# {'city_name': 'port macquarie', 'country_code': 'au'}
# <citipy.citipy.City object at 0x000001FC923E61C8>
# clyde river ca
# {'city_name': 'clyde river', 'country_code': 'ca'}
# <citipy.citipy.City object at 0x000001FC931604C8>
# mahebourg mu
# {'city_name': 'mahebourg', 'country_code': 'mu'}
# <citipy.citipy.City object at 0x000001FC942060C8>
# port alfred za
# {'city_name': 'port alfred', 'country_code': 'za'}
# <citipy.citipy.City object at 0x000001FC93237588>
# san patricio mx
# {'city_name': 'san patricio', 'country_code': 'mx'}
# <citipy.citipy.City object at 0x000001FC930BD788>
# sergeyevka kz
# {'city_name': 'sergeyevka', 'country_code': 'kz'}
# <citipy.citipy.City object at 0x000001FC92852B48>
# sorvag fo
# {'city_name': 'sorvag', 'country_code': 'fo'}
# <citipy.citipy.City object at 0x000001FC9336BC48>
# waipawa nz
# {'city_name': 'waipawa', 'country_code': 'nz'}
# <citipy.citipy.City object at 0x000001FC93CAD2C8>
# vaini to
# {'city_name': 'vaini', 'country_code': 'to'}
# <citipy.citipy.City object at 0x000001FC93DDF508>
# fortuna us
# {'city_name': 'fortuna', 'country_code': 'us'}
# <citipy.citipy.City object at 0x000001FC92186948>
# new norfolk au
# {'city_name': 'new norfolk', 'country_code': 'au'}
# <citipy.citipy.City object at 0x000001FC93237B88>
# san quintin mx
# {'city_name': 'san quintin', 'country_code': 'mx'}
# <citipy.citipy.City object at 0x000001FC933C82C8>
# rikitea pf
# {'city_name': 'rikitea', 'country_code': 'pf'}
# <citipy.citipy.City object at 0x000001FC924A6248>
# punta arenas cl
# {'city_name': 'punta arenas', 'country_code': 'cl'}
# <citipy.citipy.City object at 0x000001FC923CDA08>
# senno by
# {'city_name': 'senno', 'country_code': 'by'}
# <citipy.citipy.City object at 0x000001FC9217AB88>
# esperance au
# {'city_name': 'esperance', 'country_code': 'au'}
# <citipy.citipy.City object at 0x000001FC920F2E48>
# deh rawud af
# {'city_name': 'deh rawud', 'country_code': 'af'}
# <citipy.citipy.City object at 0x000001FC941F7C88>
# east london za
# {'city_name': 'east london', 'country_code': 'za'}
# <citipy.citipy.City object at 0x000001FC9217E3C8>
# hobart au
# {'city_name': 'hobart', 'country_code': 'au'}
# <citipy.citipy.City object at 0x000001FC94208148>
# robertson za
# {'city_name': 'robertson', 'country_code': 'za'}
# <citipy.citipy.City object at 0x000001FC924477C8>
# yellowknife ca
# {'city_name': 'yellowknife', 'country_code': 'ca'}
# <citipy.citipy.City object at 0x000001FC9244E088>
# kabinda cd
# {'city_name': 'kabinda', 'country_code': 'cd'}
# <citipy.citipy.City object at 0x000001FC92992508>
# illoqqortoormiut gl
# {'city_name': 'illoqqortoormiut', 'country_code': 'gl'}
# <citipy.citipy.City object at 0x000001FC93CAD2C8>
# vaini to
# {'city_name': 'vaini', 'country_code': 'to'}
# <citipy.citipy.City object at 0x000001FC93DB7348>
# barrow us
# {'city_name': 'barrow', 'country_code': 'us'}
# ...
# <citipy.citipy.City object at 0x000001FC93C09508>
# jamestown sh
# {'city_name': 'jamestown', 'country_code': 'sh'}
# <citipy.citipy.City object at 0x000001FC94206208>
# port elizabeth za
# {'city_name': 'port elizabeth', 'country_code': 'za'}
# <citipy.citipy.City object at 0x000001FC930BFF88>
# turkistan kz
# {'city_name': 'turkistan', 'country_code': 'kz'}
# <citipy.citipy.City object at 0x000001FC92189688>
# port hedland au
# {'city_name': 'port hedland', 'country_code': 'au'}
# <citipy.citipy.City object at 0x000001FC931604C8>
# mahebourg mu
# {'city_name': 'mahebourg', 'country_code': 'mu'}
# <citipy.citipy.City object at 0x000001FC93E6A4C8>
# kapaa us
# {'city_name': 'kapaa', 'country_code': 'us'}
# <citipy.citipy.City object at 0x000001FC933C82C8>
# rikitea pf
# {'city_name': 'rikitea', 'country_code': 'pf'}
# <citipy.citipy.City object at 0x000001FC93BEDD88>
# victoria sc
# {'city_name': 'victoria', 'country_code': 'sc'}
# <citipy.citipy.City object at 0x000001FC936F9B48>
# ribeira grande pt
# {'city_name': 'ribeira grande', 'country_code': 'pt'}
# <citipy.citipy.City object at 0x000001FC92B83BC8>
# biak id
# {'city_name': 'biak', 'country_code': 'id'}
# <citipy.citipy.City object at 0x000001FC933CFE48>
# vanimo pg
# {'city_name': 'vanimo', 'country_code': 'pg'}
# <citipy.citipy.City object at 0x000001FC941FC9C8>
# hermanus za
# {'city_name': 'hermanus', 'country_code': 'za'}
# <citipy.citipy.City object at 0x000001FC9328FC08>
# keningau my
# {'city_name': 'keningau', 'country_code': 'my'}
# <citipy.citipy.City object at 0x000001FC924CEA88>
# erenhot cn
# {'city_name': 'erenhot', 'country_code': 'cn'}
# <citipy.citipy.City object at 0x000001FC92FA8748>
# scottsbluff us
# {'city_name': 'scottsbluff', 'country_code': 'us'}
# <citipy.citipy.City object at 0x000001FC93358088>
# bluff nz
# {'city_name': 'bluff', 'country_code': 'nz'}
# <citipy.citipy.City object at 0x000001FC928C0948>
# romilly-sur-seine fr
# {'city_name': 'romilly-sur-seine', 'country_code': 'fr'}
# <citipy.citipy.City object at 0x000001FC929928C8>
# maniitsoq gl
# {'city_name': 'maniitsoq', 'country_code': 'gl'}
# <citipy.citipy.City object at 0x000001FC933CFE48>
# vanimo pg
# {'city_name': 'vanimo', 'country_code': 'pg'}
# <citipy.citipy.City object at 0x000001FC933ABFC8>
# marcona pe
# {'city_name': 'marcona', 'country_code': 'pe'}
# <citipy.citipy.City object at 0x000001FC9227E7C8>
# arraial do cabo br
# {'city_name': 'arraial do cabo', 'country_code': 'br'}
# <citipy.citipy.City object at 0x000001FC92992F08>
# qaanaaq gl
# {'city_name': 'qaanaaq', 'country_code': 'gl'}
# <citipy.citipy.City object at 0x000001FC924F5448>
# linxia cn
# {'city_name': 'linxia', 'country_code': 'cn'}
# <citipy.citipy.City object at 0x000001FC927B36C8>
# puerto ayora ec
# {'city_name': 'puerto ayora', 'country_code': 'ec'}
# <citipy.citipy.City object at 0x000001FC92BA26C8>
# meulaboh id
# {'city_name': 'meulaboh', 'country_code': 'id'}
# <citipy.citipy.City object at 0x000001FC93DE1F48>
# half moon bay us
# {'city_name': 'half moon bay', 'country_code': 'us'}
# <citipy.citipy.City object at 0x000001FC934E5348>
# la paz ph
# {'city_name': 'la paz', 'country_code': 'ph'}
# <citipy.citipy.City object at 0x000001FC939751C8>
# chagda ru
# {'city_name': 'chagda', 'country_code': 'ru'}
# <citipy.citipy.City object at 0x000001FC933CD148>
# kavieng pg
# {'city_name': 'kavieng', 'country_code': 'pg'}
# <citipy.citipy.City object at 0x000001FC92143688>
# mar del plata ar
# {'city_name': 'mar del plata', 'country_code': 'ar'}
# <citipy.citipy.City object at 0x000001FC93A8C288>
# nikolskoye ru
# {'city_name': 'nikolskoye', 'country_code': 'ru'}
# <citipy.citipy.City object at 0x000001FC9241E188>
# port hardy ca
# {'city_name': 'port hardy', 'country_code': 'ca'}
# <citipy.citipy.City object at 0x000001FC9328F988>
# kapit my
# {'city_name': 'kapit', 'country_code': 'my'}
# <citipy.citipy.City object at 0x000001FC92CCF588>
# kavaratti in
# {'city_name': 'kavaratti', 'country_code': 'in'}
# <citipy.citipy.City object at 0x000001FC92992508>
# illoqqortoormiut gl
# {'city_name': 'illoqqortoormiut', 'country_code': 'gl'}
# <citipy.citipy.City object at 0x000001FC92171208>
# albany au
# {'city_name': 'albany', 'country_code': 'au'}
# <citipy.citipy.City object at 0x000001FC93B13488>
# sentyabrskiy ru
# {'city_name': 'sentyabrskiy', 'country_code': 'ru'}
# <citipy.citipy.City object at 0x000001FC93E15BC8>
# clifton us
# {'city_name': 'clifton', 'country_code': 'us'}
# <citipy.citipy.City object at 0x000001FC927B36C8>
# puerto ayora ec
# {'city_name': 'puerto ayora', 'country_code': 'ec'}
# <citipy.citipy.City object at 0x000001FC93B69908>
# tiksi ru
# {'city_name': 'tiksi', 'country_code': 'ru'}
# <citipy.citipy.City object at 0x000001FC93A16848>
# kraskino ru
# {'city_name': 'kraskino', 'country_code': 'ru'}
# <citipy.citipy.City object at 0x000001FC9243D588>
# tuktoyaktuk ca
# {'city_name': 'tuktoyaktuk', 'country_code': 'ca'}
# <citipy.citipy.City object at 0x000001FC93C89148>
# ranong th
# {'city_name': 'ranong', 'country_code': 'th'}
# <citipy.citipy.City object at 0x000001FC92985248>
# cayenne gf
# {'city_name': 'cayenne', 'country_code': 'gf'}
# <citipy.citipy.City object at 0x000001FC9213CE88>
# soyo ao
# {'city_name': 'soyo', 'country_code': 'ao'}
# <citipy.citipy.City object at 0x000001FC92503E08>
# puqi cn
# {'city_name': 'puqi', 'country_code': 'cn'}
# <citipy.citipy.City object at 0x000001FC9321ECC8>
# praxedis guerrero mx
# {'city_name': 'praxedis guerrero', 'country_code': 'mx'}
# <citipy.citipy.City object at 0x000001FC93358088>
# bluff nz
# {'city_name': 'bluff', 'country_code': 'nz'}
# <citipy.citipy.City object at 0x000001FC9217AB88>
# esperance au
# {'city_name': 'esperance', 'country_code': 'au'}
# <citipy.citipy.City object at 0x000001FC93E6A4C8>
# kapaa us
# {'city_name': 'kapaa', 'country_code': 'us'}
# <citipy.citipy.City object at 0x000001FC93BED608>
# buala sb
# {'city_name': 'buala', 'country_code': 'sb'}
# <citipy.citipy.City object at 0x000001FC93E6A108>
# kahului us
# {'city_name': 'kahului', 'country_code': 'us'}
# <citipy.citipy.City object at 0x000001FC94206208>
# port elizabeth za
# {'city_name': 'port elizabeth', 'country_code': 'za'}
# <citipy.citipy.City object at 0x000001FC92BDC048>
# westport ie
# {'city_name': 'westport', 'country_code': 'ie'}
# <citipy.citipy.City object at 0x000001FC9213E648>
# bell ville ar
# {'city_name': 'bell ville', 'country_code': 'ar'}
# <citipy.citipy.City object at 0x000001FC93C1BC08>
# barentsburg sj
# {'city_name': 'barentsburg', 'country_code': 'sj'}
# <citipy.citipy.City object at 0x000001FC93B7AE48>
# turukhansk ru
# {'city_name': 'turukhansk', 'country_code': 'ru'}
# <citipy.citipy.City object at 0x000001FC9334FD88>
# banepa np
# {'city_name': 'banepa', 'country_code': 'np'}
# <citipy.citipy.City object at 0x000001FC92B83948>
# bengkulu id
# {'city_name': 'bengkulu', 'country_code': 'id'}
# <citipy.citipy.City object at 0x000001FC92CE1588>
# kolaras in
# {'city_name': 'kolaras', 'country_code': 'in'}
# <citipy.citipy.City object at 0x000001FC93CAD2C8>
# vaini to
# {'city_name': 'vaini', 'country_code': 'to'}
# <citipy.citipy.City object at 0x000001FC924EDCC8>
# lasa cn
# {'city_name': 'lasa', 'country_code': 'cn'}
# <citipy.citipy.City object at 0x000001FC939ECF08>
# khatanga ru
# {'city_name': 'khatanga', 'country_code': 'ru'}
# <citipy.citipy.City object at 0x000001FC92B8ED08>
# ende id
# {'city_name': 'ende', 'country_code': 'id'}
# <citipy.citipy.City object at 0x000001FC941E4D88>
# vaitupu wf
# {'city_name': 'vaitupu', 'country_code': 'wf'}
# <citipy.citipy.City object at 0x000001FC9311C888>
# ambovombe mg
# {'city_name': 'ambovombe', 'country_code': 'mg'}
# <citipy.citipy.City object at 0x000001FC92171208>
# albany au
# {'city_name': 'albany', 'country_code': 'au'}
# <citipy.citipy.City object at 0x000001FC93B0D6C8>
# saskylakh ru
# {'city_name': 'saskylakh', 'country_code': 'ru'}
# <citipy.citipy.City object at 0x000001FC924A6248>
# punta arenas cl
# {'city_name': 'punta arenas', 'country_code': 'cl'}
# <citipy.citipy.City object at 0x000001FC929DDB08>
# karpathos gr
# {'city_name': 'karpathos', 'country_code': 'gr'}
# <citipy.citipy.City object at 0x000001FC941F5848>
# cape town za
# {'city_name': 'cape town', 'country_code': 'za'}
# <citipy.citipy.City object at 0x000001FC93DB7488>
# bethel us
# {'city_name': 'bethel', 'country_code': 'us'}
# <citipy.citipy.City object at 0x000001FC939B2208>
# gornyy ru
# {'city_name': 'gornyy', 'country_code': 'ru'}
# <citipy.citipy.City object at 0x000001FC942060C8>
# port alfred za
# {'city_name': 'port alfred', 'country_code': 'za'}
# <citipy.citipy.City object at 0x000001FC93C093C8>
# georgetown sh
# {'city_name': 'georgetown', 'country_code': 'sh'}
# <citipy.citipy.City object at 0x000001FC933C82C8>
# rikitea pf
# {'city_name': 'rikitea', 'country_code': 'pf'}
# <citipy.citipy.City object at 0x000001FC92414C48>
# norman wells ca
# {'city_name': 'norman wells', 'country_code': 'ca'}
# <citipy.citipy.City object at 0x000001FC9243D588>
# tuktoyaktuk ca
# {'city_name': 'tuktoyaktuk', 'country_code': 'ca'}
# <citipy.citipy.City object at 0x000001FC9213C0C8>
# luanda ao
# {'city_name': 'luanda', 'country_code': 'ao'}
# <citipy.citipy.City object at 0x000001FC93BE1108>
# zhigalovo ru
# {'city_name': 'zhigalovo', 'country_code': 'ru'}
# <citipy.citipy.City object at 0x000001FC93CAD2C8>
# vaini to
# {'city_name': 'vaini', 'country_code': 'to'}
# <citipy.citipy.City object at 0x000001FC93647508>
# bela pk
# {'city_name': 'bela', 'country_code': 'pk'}
# <citipy.citipy.City object at 0x000001FC92602B48>
# ponta do sol cv
# {'city_name': 'ponta do sol', 'country_code': 'cv'}
# <citipy.citipy.City object at 0x000001FC93C09508>
# jamestown sh
# {'city_name': 'jamestown', 'country_code': 'sh'}
# <citipy.citipy.City object at 0x000001FC92176588>
# busselton au
# {'city_name': 'busselton', 'country_code': 'au'}
# <citipy.citipy.City object at 0x000001FC9237DBC8>
# sao bernardo br
# {'city_name': 'sao bernardo', 'country_code': 'br'}
# <citipy.citipy.City object at 0x000001FC933C82C8>
# rikitea pf
# {'city_name': 'rikitea', 'country_code': 'pf'}
# <citipy.citipy.City object at 0x000001FC939D9088>
# kamyshin ru
# {'city_name': 'kamyshin', 'country_code': 'ru'}
# <citipy.citipy.City object at 0x000001FC933C82C8>
# rikitea pf
# {'city_name': 'rikitea', 'country_code': 'pf'}
# <citipy.citipy.City object at 0x000001FC93A85B08>
# nevelsk ru
# {'city_name': 'nevelsk', 'country_code': 'ru'}
# <citipy.citipy.City object at 0x000001FC9232FF48>
# natal br
# {'city_name': 'natal', 'country_code': 'br'}
# <citipy.citipy.City object at 0x000001FC92B83948>
# bengkulu id
# {'city_name': 'bengkulu', 'country_code': 'id'}
# <citipy.citipy.City object at 0x000001FC94180308>
# washington us
# {'city_name': 'washington', 'country_code': 'us'}
# <citipy.citipy.City object at 0x000001FC939ECF08>
# khatanga ru
# {'city_name': 'khatanga', 'country_code': 'ru'}
# <citipy.citipy.City object at 0x000001FC933CBE88>
# kainantu pg
# {'city_name': 'kainantu', 'country_code': 'pg'}
# <citipy.citipy.City object at 0x000001FC93B61048>
# tarko-sale ru
# {'city_name': 'tarko-sale', 'country_code': 'ru'}
# <citipy.citipy.City object at 0x000001FC93931908>
# anadyr ru
# {'city_name': 'anadyr', 'country_code': 'ru'}
# <citipy.citipy.City object at 0x000001FC93926B48>
# aksarka ru
# {'city_name': 'aksarka', 'country_code': 'ru'}
# <citipy.citipy.City object at 0x000001FC92171208>
# albany au
# {'city_name': 'albany', 'country_code': 'au'}
# <citipy.citipy.City object at 0x000001FC92F23C08>
# shimoda jp
# {'city_name': 'shimoda', 'country_code': 'jp'}
# <citipy.citipy.City object at 0x000001FC93314488>
# berlevag no
# {'city_name': 'berlevag', 'country_code': 'no'}
# <citipy.citipy.City object at 0x000001FC933C4448>
# atuona pf
# {'city_name': 'atuona', 'country_code': 'pf'}
# <citipy.citipy.City object at 0x000001FC9243BC88>
# torbay ca
# {'city_name': 'torbay', 'country_code': 'ca'}
# <citipy.citipy.City object at 0x000001FC942060C8>
# port alfred za
# {'city_name': 'port alfred', 'country_code': 'za'}
# <citipy.citipy.City object at 0x000001FC92499C08>
# avarua ck
# {'city_name': 'avarua', 'country_code': 'ck'}
# <citipy.citipy.City object at 0x000001FC93BF2848>
# marawi sd
# {'city_name': 'marawi', 'country_code': 'sd'}
# <citipy.citipy.City object at 0x000001FC92425EC8>
# saint anthony ca
# {'city_name': 'saint anthony', 'country_code': 'ca'}
# <citipy.citipy.City object at 0x000001FC92148FC8>
# ushuaia ar
# {'city_name': 'ushuaia', 'country_code': 'ar'}
# <citipy.citipy.City object at 0x000001FC9394E9C8>
# belaya gora ru
# {'city_name': 'belaya gora', 'country_code': 'ru'}
# <citipy.citipy.City object at 0x000001FC93C42C48>
# bandarbeyla so
# {'city_name': 'bandarbeyla', 'country_code': 'so'}
# <citipy.citipy.City object at 0x000001FC931DA488>
# isla mujeres mx
# {'city_name': 'isla mujeres', 'country_code': 'mx'}
# <citipy.citipy.City object at 0x000001FC941DE348>
# hue vn
# {'city_name': 'hue', 'country_code': 'vn'}
# <citipy.citipy.City object at 0x000001FC924477C8>
# yellowknife ca
# {'city_name': 'yellowknife', 'country_code': 'ca'}
# <citipy.citipy.City object at 0x000001FC92414C48>
# norman wells ca
# {'city_name': 'norman wells', 'country_code': 'ca'}
# <citipy.citipy.City object at 0x000001FC932A0D48>
# inhambane mz
# {'city_name': 'inhambane', 'country_code': 'mz'}
# <citipy.citipy.City object at 0x000001FC941F5848>
# cape town za
# {'city_name': 'cape town', 'country_code': 'za'}
# <citipy.citipy.City object at 0x000001FC9243EEC8>
# ville-marie ca
# {'city_name': 'ville-marie', 'country_code': 'ca'}
# <citipy.citipy.City object at 0x000001FC93E6A108>
# kahului us
# {'city_name': 'kahului', 'country_code': 'us'}
# <citipy.citipy.City object at 0x000001FC93C09508>
# jamestown sh
# {'city_name': 'jamestown', 'country_code': 'sh'}
# <citipy.citipy.City object at 0x000001FC926EE308>
# lauterbach de
# {'city_name': 'lauterbach', 'country_code': 'de'}
# <citipy.citipy.City object at 0x000001FC9227E7C8>
# arraial do cabo br
# {'city_name': 'arraial do cabo', 'country_code': 'br'}
# <citipy.citipy.City object at 0x000001FC92A5AC48>
# champerico gt
# {'city_name': 'champerico', 'country_code': 'gt'}
# <citipy.citipy.City object at 0x000001FC933C74C8>
# mataura pf
# {'city_name': 'mataura', 'country_code': 'pf'}
# <citipy.citipy.City object at 0x000001FC92148FC8>
# ushuaia ar
# {'city_name': 'ushuaia', 'country_code': 'ar'}
# <citipy.citipy.City object at 0x000001FC92176588>
# busselton au
# {'city_name': 'busselton', 'country_code': 'au'}
# <citipy.citipy.City object at 0x000001FC924EC108>
# kaitong cn
# {'city_name': 'kaitong', 'country_code': 'cn'}
# <citipy.citipy.City object at 0x000001FC941F9A88>
# george za
# {'city_name': 'george', 'country_code': 'za'}
# <citipy.citipy.City object at 0x000001FC93D12A88>
# sumbawanga tz
# {'city_name': 'sumbawanga', 'country_code': 'tz'}
# <citipy.citipy.City object at 0x000001FC92433A08>
# steinbach ca
# {'city_name': 'steinbach', 'country_code': 'ca'}
# <citipy.citipy.City object at 0x000001FC939751C8>
# chagda ru
# {'city_name': 'chagda', 'country_code': 'ru'}
# <citipy.citipy.City object at 0x000001FC9226CDC8>
# alta floresta br
# {'city_name': 'alta floresta', 'country_code': 'br'}
# <citipy.citipy.City object at 0x000001FC925248C8>
# yanan cn
# {'city_name': 'yanan', 'country_code': 'cn'}
# <citipy.citipy.City object at 0x000001FC92992F08>
# qaanaaq gl
# {'city_name': 'qaanaaq', 'country_code': 'gl'}
# <citipy.citipy.City object at 0x000001FC931CD908>
# guerrero negro mx
# {'city_name': 'guerrero negro', 'country_code': 'mx'}
# <citipy.citipy.City object at 0x000001FC92143688>
# mar del plata ar
# {'city_name': 'mar del plata', 'country_code': 'ar'}
# <citipy.citipy.City object at 0x000001FC92148FC8>
# ushuaia ar
# {'city_name': 'ushuaia', 'country_code': 'ar'}
# <citipy.citipy.City object at 0x000001FC93AD1948>
# pevek ru
# {'city_name': 'pevek', 'country_code': 'ru'}
# <citipy.citipy.City object at 0x000001FC93C093C8>
# georgetown sh
# {'city_name': 'georgetown', 'country_code': 'sh'}
# <citipy.citipy.City object at 0x000001FC92499D48>
# ancud cl
# {'city_name': 'ancud', 'country_code': 'cl'}
# <citipy.citipy.City object at 0x000001FC92602B48>
# ponta do sol cv
# {'city_name': 'ponta do sol', 'country_code': 'cv'}
# <citipy.citipy.City object at 0x000001FC93A400C8>
# lavrentiya ru
# {'city_name': 'lavrentiya', 'country_code': 'ru'}
# <citipy.citipy.City object at 0x000001FC92176588>
# busselton au
# {'city_name': 'busselton', 'country_code': 'au'}
# <citipy.citipy.City object at 0x000001FC941F5848>
# cape town za
# {'city_name': 'cape town', 'country_code': 'za'}
# <citipy.citipy.City object at 0x000001FC92176588>
# busselton au
# {'city_name': 'busselton', 'country_code': 'au'}
# 624
